# %% [markdown]
# # Using the default catalog
#
# `intake_esgf` comes with a default catalog.
#
# This default catalog is ment to resemble the projects within CoG.
#
# Below we'll start by import `intake` and calling `open_esgf_default_catalog`.

# %%
import intake

cat = intake.open_esgf_default_catalog()

# %% [markdown]
# # List the available sources
#
# Now we can list the available sources and explore the facets belonging to them.

# %%
list(cat)
# Out:
# ['cmip5', 'cmip6', 'e3sm', 'cmip3', 'input4mips', 'obs4mips', 'create_ip']

# %%
cat.cmip6.facet_values(True)
# Out:
# AppLayout(children=(Output(layout=Layout(grid_area='footer')), Dropdown(layout=Layout(grid_area='left-sidebar'…

# %%
cat.e3sm.facet_values(True)
# Out:
# AppLayout(children=(Output(layout=Layout(grid_area='footer')), Dropdown(layout=Layout(grid_area='left-sidebar'…

# %% [markdown]
# # Search for data using a source
#
# We can use the sources to begin searching for data using the facets from above.

# %%
results = cat.cmip6.search(variable="clt", frequency="mon")
results
# Out:
#                                                    id activity_id  \
# 0   CMIP6.AerChemMIP.AS-RCEC.TaiESM1.histSST.r1i1p...  AerChemMIP
# 1   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r1i1p...  AerChemMIP
# 2   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r1i1p...  AerChemMIP
# 3   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r2i1p...  AerChemMIP
# 4   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r2i1p...  AerChemMIP
# ..                                                ...         ...
# 95  CMIP6.AerChemMIP.CNRM-CERFACS.CNRM-ESM2-1.hist...  AerChemMIP
# 96  CMIP6.AerChemMIP.CNRM-CERFACS.CNRM-ESM2-1.hist...  AerChemMIP
# 97  CMIP6.AerChemMIP.CNRM-CERFACS.CNRM-ESM2-1.hist...  AerChemMIP
# 98  CMIP6.AerChemMIP.CNRM-CERFACS.CNRM-ESM2-1.hist...  AerChemMIP
# 99  CMIP6.AerChemMIP.CNRM-CERFACS.CNRM-ESM2-1.hist...  AerChemMIP
#
#        cf_standard_name experiment_id frequency  \
# 0   cloud_area_fraction       histSST       mon
# 1   cloud_area_fraction       histSST       mon
# 2   cloud_area_fraction       histSST       mon
# 3   cloud_area_fraction       histSST       mon
# 4   cloud_area_fraction       histSST       mon
# ..                  ...           ...       ...
# 95  cloud_area_fraction       histSST       mon
# 96  cloud_area_fraction       histSST       mon
# 97  cloud_area_fraction       histSST       mon
# 98  cloud_area_fraction       histSST       mon
# 99  cloud_area_fraction       histSST       mon
#
#                                                  grid grid_label  \
# 0   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 1   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 2   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 3   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 4   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# ..                                                ...        ...
# 95  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 96  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 97  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 98  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 99  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
#
#    institution_id mip_era model_cohort nominal_resolution  \
# 0         AS-RCEC   CMIP6   Registered             100 km
# 1         AS-RCEC   CMIP6   Registered             100 km
# 2         AS-RCEC   CMIP6   Registered             100 km
# 3         AS-RCEC   CMIP6   Registered             100 km
# 4         AS-RCEC   CMIP6   Registered             100 km
# ..            ...     ...          ...                ...
# 95        AS-RCEC   CMIP6   Registered             100 km
# 96        AS-RCEC   CMIP6   Registered             100 km
# 97        AS-RCEC   CMIP6   Registered             100 km
# 98        AS-RCEC   CMIP6   Registered             100 km
# 99        AS-RCEC   CMIP6   Registered             100 km
#
#                                                   pid       product project  \
# 0   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 1   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 2   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 3   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 4   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# ..                                                ...           ...     ...
# 95  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 96  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 97  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 98  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 99  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
#
#     realm                                                url variable  score
# 0   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 1   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 2   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 3   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 4   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# ..    ...                                                ...      ...    ...
# 95  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 96  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 97  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 98  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 99  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
#
# [100 rows x 18 columns]
# AppLayout(children=(HBox(children=(Button(button_style='success', description='variable: clt', style=ButtonSty…
