# %% [markdown]
# # Searching
#
# The following demo will covering using intake to search ESGF.

# %%
import intake

# %% [markdown]
# ## Configuring search

# %%
kwargs = {
    "url": "https://esgf-node.llnl.gov/esg-search/search",
    "preset": "CMIP6",
    "facets": {
        "variable": ["tas", "clt"],
    },
    "chunks": {
        "time": 100,
    }
}

cat = intake.open_esgf_catalog(**kwargs)

# %% [markdown]
# ## Start exploring results

# %%
len(cat)
# Out:
# 819677

# %%
cat
# Out:
#                                                    id activity_id  \
# 0   CMIP6.AerChemMIP.AS-RCEC.TaiESM1.histSST.r1i1p...  AerChemMIP
# 1   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r1i1p...  AerChemMIP
# 2   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r1i1p...  AerChemMIP
# 3   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r1i1p...  AerChemMIP
# 4   CMIP6.AerChemMIP.BCC.BCC-ESM1.hist-piAer.r1i1p...  AerChemMIP
# ..                                                ...         ...
# 95  CMIP6.AerChemMIP.BCC.BCC-ESM1.piClim-NOx.r1i1p...  AerChemMIP
# 96  CMIP6.AerChemMIP.BCC.BCC-ESM1.piClim-NOx.r1i1p...  AerChemMIP
# 97  CMIP6.AerChemMIP.BCC.BCC-ESM1.piClim-NOx.r1i1p...  AerChemMIP
# 98  CMIP6.AerChemMIP.BCC.BCC-ESM1.piClim-NTCF.r1i1...  AerChemMIP
# 99  CMIP6.AerChemMIP.BCC.BCC-ESM1.piClim-NTCF.r1i1...  AerChemMIP
#
#        cf_standard_name experiment_id frequency  \
# 0   cloud_area_fraction       histSST       mon
# 1   cloud_area_fraction       histSST       mon
# 2   cloud_area_fraction       histSST       mon
# 3   cloud_area_fraction       histSST       mon
# 4   cloud_area_fraction       histSST       mon
# ..                  ...           ...       ...
# 95  cloud_area_fraction       histSST       mon
# 96  cloud_area_fraction       histSST       mon
# 97  cloud_area_fraction       histSST       mon
# 98  cloud_area_fraction       histSST       mon
# 99  cloud_area_fraction       histSST       mon
#
#                                                  grid grid_label  \
# 0   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 1   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 2   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 3   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 4   finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# ..                                                ...        ...
# 95  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 96  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 97  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 98  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
# 99  finite-volume grid with 0.9x1.25 degree lat/lo...         gn
#
#    institution_id mip_era model_cohort nominal_resolution  \
# 0         AS-RCEC   CMIP6   Registered             100 km
# 1         AS-RCEC   CMIP6   Registered             100 km
# 2         AS-RCEC   CMIP6   Registered             100 km
# 3         AS-RCEC   CMIP6   Registered             100 km
# 4         AS-RCEC   CMIP6   Registered             100 km
# ..            ...     ...          ...                ...
# 95        AS-RCEC   CMIP6   Registered             100 km
# 96        AS-RCEC   CMIP6   Registered             100 km
# 97        AS-RCEC   CMIP6   Registered             100 km
# 98        AS-RCEC   CMIP6   Registered             100 km
# 99        AS-RCEC   CMIP6   Registered             100 km
#
#                                                   pid       product project  \
# 0   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 1   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 2   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 3   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 4   hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# ..                                                ...           ...     ...
# 95  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 96  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 97  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 98  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
# 99  hdl:21.14100/1952f3a6-e2fa-3ea7-851a-05b9ba60434f  model-output   CMIP6
#
#     realm                                                url variable  score
# 0   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 1   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 2   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 3   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 4   atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# ..    ...                                                ...      ...    ...
# 95  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 96  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 97  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 98  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
# 99  atmos  http://esgf.rcec.sinica.edu.tw/thredds/fileSer...      clt    1.0
#
# [100 rows x 18 columns]

# %% [markdown]
# # Refining search criteria

# %%
cat.facet_values(True)

# %%
sub_cat = cat.search(experiment_id="amip", frequency="3hr", data_node="aims3.llnl.gov")

len(sub_cat)
# Out:
# 16

# %%
list(sub_cat)
# Out:
# ['CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.amip.r1i1p1f2.3hr.clt.gr.v20181203.clt_3hr_CNRM-CM6-1_amip_r1i1p1f2_gr_197901010130-200312312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.amip.r1i1p1f2.3hr.clt.gr.v20181203.clt_3hr_CNRM-CM6-1_amip_r1i1p1f2_gr_200401010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.amip.r1i1p1f2.3hr.clt.gr.v20181205.clt_3hr_CNRM-ESM2-1_amip_r1i1p1f2_gr_197901010130-200312312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.amip.r1i1p1f2.3hr.clt.gr.v20181205.clt_3hr_CNRM-ESM2-1_amip_r1i1p1f2_gr_200401010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r10i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r10i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r11i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r11i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r1i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r1i1p1f1_gr_197901010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r1i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r1i1p1f1_gr_201501010130-201712312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r2i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r2i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r3i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r3i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r4i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r4i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r5i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r5i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r6i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r6i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r7i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r7i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r8i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r8i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov',
#  'CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r9i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r9i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov']

# %%
sub_cat
# Out:
#                                                    id activity_id  \
# 0   CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.amip.r1i1p1...        CMIP
# 1   CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.amip.r1i1p1...        CMIP
# 2   CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.amip.r1i1p...        CMIP
# 3   CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.amip.r1i1p...        CMIP
# 4   CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r10i1p1f1.3h...        CMIP
# 5   CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r11i1p1f1.3h...        CMIP
# 6   CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r1i1p1f1.3hr...        CMIP
# 7   CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r1i1p1f1.3hr...        CMIP
# 8   CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r2i1p1f1.3hr...        CMIP
# 9   CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r3i1p1f1.3hr...        CMIP
# 10  CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r4i1p1f1.3hr...        CMIP
# 11  CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r5i1p1f1.3hr...        CMIP
# 12  CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r6i1p1f1.3hr...        CMIP
# 13  CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r7i1p1f1.3hr...        CMIP
# 14  CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r8i1p1f1.3hr...        CMIP
# 15  CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r9i1p1f1.3hr...        CMIP
#
#        cf_standard_name experiment_id frequency  \
# 0   cloud_area_fraction          amip       3hr
# 1   cloud_area_fraction          amip       3hr
# 2   cloud_area_fraction          amip       3hr
# 3   cloud_area_fraction          amip       3hr
# 4   cloud_area_fraction          amip       3hr
# 5   cloud_area_fraction          amip       3hr
# 6   cloud_area_fraction          amip       3hr
# 7   cloud_area_fraction          amip       3hr
# 8   cloud_area_fraction          amip       3hr
# 9   cloud_area_fraction          amip       3hr
# 10  cloud_area_fraction          amip       3hr
# 11  cloud_area_fraction          amip       3hr
# 12  cloud_area_fraction          amip       3hr
# 13  cloud_area_fraction          amip       3hr
# 14  cloud_area_fraction          amip       3hr
# 15  cloud_area_fraction          amip       3hr
#
#                                                  grid grid_label  \
# 0   data regridded to a T127 gaussian grid (128x25...         gr
# 1   data regridded to a T127 gaussian grid (128x25...         gr
# 2   data regridded to a T127 gaussian grid (128x25...         gr
# 3   data regridded to a T127 gaussian grid (128x25...         gr
# 4   data regridded to a T127 gaussian grid (128x25...         gr
# 5   data regridded to a T127 gaussian grid (128x25...         gr
# 6   data regridded to a T127 gaussian grid (128x25...         gr
# 7   data regridded to a T127 gaussian grid (128x25...         gr
# 8   data regridded to a T127 gaussian grid (128x25...         gr
# 9   data regridded to a T127 gaussian grid (128x25...         gr
# 10  data regridded to a T127 gaussian grid (128x25...         gr
# 11  data regridded to a T127 gaussian grid (128x25...         gr
# 12  data regridded to a T127 gaussian grid (128x25...         gr
# 13  data regridded to a T127 gaussian grid (128x25...         gr
# 14  data regridded to a T127 gaussian grid (128x25...         gr
# 15  data regridded to a T127 gaussian grid (128x25...         gr
#
#    institution_id mip_era model_cohort nominal_resolution  \
# 0    CNRM-CERFACS   CMIP6   Registered             250 km
# 1    CNRM-CERFACS   CMIP6   Registered             250 km
# 2    CNRM-CERFACS   CMIP6   Registered             250 km
# 3    CNRM-CERFACS   CMIP6   Registered             250 km
# 4    CNRM-CERFACS   CMIP6   Registered             250 km
# 5    CNRM-CERFACS   CMIP6   Registered             250 km
# 6    CNRM-CERFACS   CMIP6   Registered             250 km
# 7    CNRM-CERFACS   CMIP6   Registered             250 km
# 8    CNRM-CERFACS   CMIP6   Registered             250 km
# 9    CNRM-CERFACS   CMIP6   Registered             250 km
# 10   CNRM-CERFACS   CMIP6   Registered             250 km
# 11   CNRM-CERFACS   CMIP6   Registered             250 km
# 12   CNRM-CERFACS   CMIP6   Registered             250 km
# 13   CNRM-CERFACS   CMIP6   Registered             250 km
# 14   CNRM-CERFACS   CMIP6   Registered             250 km
# 15   CNRM-CERFACS   CMIP6   Registered             250 km
#
#                                                   pid       product project  \
# 0   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 1   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 2   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 3   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 4   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 5   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 6   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 7   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 8   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 9   hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 10  hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 11  hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 12  hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 13  hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 14  hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
# 15  hdl:21.14100/71ee3429-e836-3540-985e-7e34cb5e86dc  model-output   CMIP6
#
#     realm                                                url variable  score
# 0   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 1   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 2   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 3   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 4   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 5   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 6   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 7   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 8   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 9   atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 10  atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 11  atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 12  atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 13  atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 14  atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0
# 15  atmos  [http://aims3.llnl.gov/thredds/fileServer/css0...      clt    1.0

# %% [markdown]
# ## Access the data

# %%
entry = sub_cat['CMIP6.CMIP.IPSL.IPSL-CM6A-LR.amip.r9i1p1f1.3hr.clt.gr.v20181109.clt_3hr_IPSL-CM6A-LR_amip_r9i1p1f1_gr_195801010130-201412312230.nc|aims3.llnl.gov']
entry
# Out:
# netcdf:
#   args:
#     chunks:
#       time: 100
#     storage_options: {}
#     urlpath: http://aims3.llnl.gov/thredds/dodsC/css03_data/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/amip/r9i1p1f1/3hr/clt/gr/v20181109/clt_3hr_IPSL-CM6A-LR_amip_r9i1p1f1_gr_195801010130-201412312230.nc
#     xarray_kwargs: {}
#   description: ''
#   driver: intake_xarray.netcdf.NetCDFSource
#   metadata: {}

# %%
data = entry.read_chunked()
data
# Out:
# <xarray.Dataset>
# Dimensions:      (axis_nbounds: 2, lat: 143, lon: 144, time: 166552)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73239 -87.46479 ... 88.73239 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time         (time) datetime64[ns] 1958-01-01T01:30:00 ... 2014-12-31T22:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] dask.array<chunksize=(100, 2), meta=np.ndarray>
#     clt          (time, lat, lon) float32 dask.array<chunksize=(100, 143, 144), meta=np.ndarray>
# Attributes:
#     Conventions:                     CF-1.7 CMIP-6.2
#     creation_date:                   2018-08-08T10:36:46Z
#     tracking_id:                     hdl:21.14100/f18ada4a-189e-4d0c-bb6a-ec5...
#     description:                     DECK: AMIP
#     title:                           IPSL-CM6A-LR model output prepared for C...
#     activity_id:                     CMIP
#     contact:                         ipsl-cmip6@listes.ipsl.fr
#     data_specs_version:              01.00.21
#     dr2xml_version:                  1.12
#     experiment_id:                   amip
#     experiment:                      AMIP
#     external_variables:              areacella
#     forcing_index:                   1
#     frequency:                       3hr
#     grid:                            LMDZ grid
#     grid_label:                      gr
#     nominal_resolution:              250 km
#     initialization_index:            1
#     institution_id:                  IPSL
#     institution:                     Institut Pierre Simon Laplace, Paris 752...
#     license:                         CMIP6 model data produced by IPSL is lic...
#     mip_era:                         CMIP6
#     physics_index:                   1
#     product:                         model-output
#     realization_index:               8
#     realm:                           atmos
#     source:                          IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6,...
#     source_id:                       IPSL-CM6A-LR
#     source_type:                     AGCM
#     sub_experiment_id:               none
#     sub_experiment:                  none
#     table_id:                        3hr
#     variable_id:                     clt
#     variant_info:                    Restart from another point in the spin u...
#     EXPID:                           amip
#     CMIP6_CV_version:                cv=6.2.3.5-2-g63b123e
#     dr2xml_md5sum:                   523ab9c7b70cfe3bc2c825d1e555e1d0
#     model_version:                   6.1.5
#     branch_method:                   no parent
#     parent_activity_id:              no parent
#     parent_experiment_id:            no parent
#     parent_mip_era:                  no parent
#     parent_source_id:                no parent
#     parent_time_units:               no parent
#     parent_variant_label:            no parent
#     name:                            /ccc/work/cont003/gencmip6/mellull/IGCM_...
#     further_info_url:                https://furtherinfo.es-doc.org/CMIP6.IPS...
#     variant_label:                   r9i1p1f1
#     history:                         Fri Nov  9 13:09:47 2018: ncatted -O -a ...
#     NCO:                             "4.6.0"
#     DODS_EXTRA.Unlimited_Dimension:  time
